# %% [markdown]
# # 📘 Full Python Study Notebook — Day 3
# At least 10 examples for each topic

# %% [markdown]
# ## 🔹 Values (10 Examples)

# %%
10
3.14
-5
0
True
False
"Hello"
'Python'
100000
"123"
# Out:
# '123'

# %% [markdown]
# ## 🔹 Expressions (10 Examples)

# %%
5 + 3
10 - 2
4 * 6
8 / 2
10 % 3
2 ** 3
7 > 5
4 == 4
"Hi" + " There"
(5 + 3) * 2
# Out:
# 16

# %% [markdown]
# ## 🔹 Statements (10 Examples)

# %%
x = 5
print(x)
y = 10
print(x + y)
name = "Ali"
print(name)
a = 1
b = 2
total = a + b
print(total)

# %% [markdown]
# ## 🔹 Numbers (10 Examples)

# %%
print(1)
print(25)
print(-10)
print(3.14)
print(0.5)
print(1000)
print(2.718)
print(999)
print(-3.5)
print(42)
# Out:
# 1
# 25
# -10
# 3.14
# 0.5
# 1000
# 2.718
# 999
# -3.5
# 42

# %% [markdown]
# ## 🔹 Booleans (10 Examples)

# %%
print(True)
print(False)
print(5 > 2)
print(3 == 4)
print(10 != 5)
print(7 <= 7)
print(8 >= 9)
print(not True)
print(True and False)
print(True or False)
# Out:
# True
# False
# True
# False
# True
# True
# False
# False
# False
# True

# %% [markdown]
# ## 🔹 Strings (10 Examples)

# %%
print("Hello")
print('World')
print("Python")
print("123")
print("A")
print("My name is Ali")
print("")
print("Hi there")
print("Good Morning")
print("AI")
# Out:
# Hello
# World
# Python
# 123
# A
# My name is Ali
#
# Hi there
# Good Morning
# AI

# %% [markdown]
# ## 🔹 Operators (10 Examples)

# %%
print(5 + 2)
print(9 - 4)
print(3 * 3)
print(8 / 2)
print(7 % 2)
print(2 ** 4)
print(9 // 2)   
print(5 > 3)
print(4 == 4)
print(6 != 1)
# Out:
# 7
# 5
# 9
# 4.0
# 1
# 16
# 4
# True
# True
# True

# %% [markdown]
# ## 🔹 Variables (10 Examples)

# %%
x = 10; print(x)
name = "Sara"; print(name)
age = 20; print(age)
price = 99.9; print(price)
is_ok = True; print(is_ok)
a = 1; b = 2; print(a+b)
city = "Lahore"; print(city)
score = 95; print(score)
temp = 37; print(temp)
year = 2025; print(year)
# Out:
# 10
# Sara
# 20
# 99.9
# True
# 3
# Lahore
# 95
# 37
# 2025

# %% [markdown]
# ## 🔹 String Operations (10 Examples)

# %%
print("Hi" + " There")
print("A" * 5)
print(len("Python"))
print("Python"[0])
print("Python"[-1])
print("Python"[0:3])
print("Hello".upper())
print("HELLO".lower())
print("  hi  ".strip())
print("banana".replace("a","o"))
# Out:
# Hi There
# AAAAA
# 6
# P
# n
# Pyt
# HELLO
# hello
# hi
# bonono

# %% [markdown]
# ## 🔹 Input (10 Examples — Uncomment to run)

# %%
name = input('Enter name: ')
age = input('Enter age: ')
city = input('City: ')
num = input('Number: ')
text = input('Text: ')
a = input('A: ')
b = input('B: ')
email = input('Email: ')
phone = input('Phone: ')
course = input('Course: ')

# %% [markdown]
# ## 🔹 Type Casting (10 Examples)

# %%
print(int("5"))
print(float("3.5"))
print(str(100))
print(int(4.9))
print(float(7))
print(str(True))
print(int("20") + 5)
print(float("2.2") * 2)
print(str(3.14))
# age = int(input('Age: '))

# %% [markdown]
# ## 🔹 Comments (10 Examples)

# %%
# This is a comment
# Python program
# Input from user
# Add two numbers
# Output result
# Loop starts here
# Condition check
# Function definition
# End of program
"""Multi-line comment example"""
print('Comments done')          # This is an inline comment
# Out:
# Comments done
