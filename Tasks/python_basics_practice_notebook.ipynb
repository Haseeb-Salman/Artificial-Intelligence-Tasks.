# %% [markdown]
# # Python Basics  Practice Notebook
# Each topic has a short explanation and 10 examples.

# %% [markdown]
# **Values, Expressions, Statements (Numbers, Booleans, Strings, Operators, Variables, Keywords)**
#
# Values basic data hoti hain. Expressions operations perform karte hain aur statements program ko action karne ke liye instructions dete hain.

# %%
a = 5
b = 15
c = 7
x = a + b / c
y = c - a * b
str = "Compare third number and update max if larger."
print(str)
print(x)
print(y)
print(a + b / c)
print(c - a * b)
# Out:
# Compare third number and update max if larger.
# 7.142857142857142
# -68
# 7.142857142857142
# -68

# %% [markdown]
# ## Day 3
# **String Operations**
#
# Strings text data hoti hain. In par join, slice, repeat, search aur modify operations kiye ja sakte hain.

# %%
s = "Python"
print(s + " Language")
s * 2
print(s[0])
print(s[1:4])
print(len(s))
print(s.lower())
print(s.upper())
print(s.replace("Py","My"))
"th" in s
print(s)
# Out:
# Python Language
# P
# yth
# 6
# python
# PYTHON
# Mython
# Python

# %% [markdown]
# **Input, Type Casting, Comments**
#
# Input user se data leta hai. Type casting data type convert karta hai aur comments code explain karne ke liye hote hain.

# %%
name = input("Enter name: ")
age = int(input("Enter age: "))
height = float("5.9")
# num = str(100)
# This is a comment
x = int("10") + 5
y = float(5)
z = bool(1)
a = bool(0)
print( name)
# Out:
# ali

# %% [markdown]
# ## Day
# **Lists & Tuples**
#
# Lists mutable hoti hain (change ho sakti hain). Tuples immutable hoti hain (change nahi hoti).

# %%
lst = [1, 4, 3]
lst.append(4)
# lst.remove(2)
lst[0]
len(lst)
tpl = (10, 5, 8)
tpl[1]
lst2 = ["Ali", "Sara", "John"]
lst2[2] = "Ayesha"
print(lst2[2])
# tpl[0] = 5  # Error (immutable)
# Out:
# Ayesha

# %% [markdown]
# ## Day
# **Dictionaries & Sets**
#
# Dictionary key-value pairs store karta hai. Set unique values store karta hai (duplicates remove ho jate hain).

# %%
d = {"name": "Ali", "age": 20}
d["name"]
d["city"] = "Lahore"
len(d)
s = {1, 2, 3, 3, 4}
s.add(5)
s.remove(2)
1 in s
set2 = set([10, 20, 20, 30])
set2
# Out:
# {10, 20, 30}

# %% [markdown]
# ## Day 5
# **Conditional Execution (if, elif, else, break, continue, pass)**
#
# Conditionals decision making ke liye use hote hain. Break loop stop karta hai, continue next iteration par jata hai aur pass placeholder hota hai.

# %%
x = 10
if x > 5:
    print("Greater")
if x < 5:
    print("Small")
else:
    print("Not small")
if x == 10:
    print("Ten")
elif x > 10:
    print("Big")
else:
    print("Other")
for i in range(5):
    if i == 3:
        break
for i in range(5):
    if i == 2:
        continue
    print(i)
for i in range(3):
    pass
# Out:
# Greater
# Not small
# Ten
# 0
# 1
# 3
# 4

# %% [markdown]
# ## Nested Conditionals
#
# Nested condition mein ek if ke andar doosra if hota hai. Yeh complex decisions ke liye use hota hai.

# %%
age = 20
citizen = True
if age >= 18:
    if citizen:
        print("Eligible")
if age >= 18:
    if not citizen:
        print("Need citizenship")
num = 15
if num > 0:
    if num % 2 == 0:
        print("Positive even")
    else:
        prnt("Positive odd")
marks = 85
if marks >= 50:
    if marks >= 80:
        print("A grade")
    elif marks >= 60:
        print("B grade")
    else:
        print("Pass")
# Out:
# Eligible
# Positive odd
# A grade

# %% [markdown]
# ## Conditional (Ternary) Expression
#
# Ternary operator single line mein if‑else likhne ka short way hai.

# %%
x = 10
result = "Positive" if x > 0 else "Negative"
age = 16
status = "Adult" if age >= 18 else "Minor"
num = 7
parity = "Even" if num % 2 == 0 else "Odd"
a, b = 5, 9
max_val = a if a > b else b
marks = 75
grade = "Pass" if marks >= 50 else "Fail"
temp = 30
weather = "Hot" if temp > 25 else "Cool"
n = 0
type_num = "Zero" if n == 0 else "Non-zero"
score = 90
msg = "Excellent" if score > 85 else "Good"
light = True
state = "On" if light else "Off"
is_logged = False
text = "Welcome" if is_logged else "Login first"
