# %%
import numpy as np
import pandas as pd

# %%
df_customer = pd.read_csv('customers.csv')
df_customer
df_sales = pd.read_csv('sales.csv')
df_sales
# Out:
#      order_id        date region   product     category customer_type  \
# 0           1  2024-04-12   East    Laptop  Electronics     Returning
# 1           2  2024-12-14  South   Monitor  Accessories     Returning
# 2           3  2024-09-27  North     Phone  Accessories           New
# 3           4  2024-04-16   West     Mouse  Electronics     Returning
# 4           5  2024-03-12   West     Phone  Electronics     Returning
# ..        ...         ...    ...       ...          ...           ...
# 495       496  2024-11-20  South     Mouse  Accessories     Returning
# 496       497  2024-01-04  North     Phone  Accessories     Returning
# 497       498  2024-01-16  South  Keyboard  Electronics     Returning
# 498       499  2024-10-06  North     Phone  Accessories     Returning
# 499       500  2024-12-01  North   Monitor  Electronics           New
#
#      quantity  price  discount    sales
# 0           8    590      0.09  4295.20
# 1           2    262      0.18   429.68
# ...

# %%
df_sales.head(3)
# Out:
#    order_id        date region  product     category customer_type  quantity  \
# 0         1  2024-04-12   East   Laptop  Electronics     Returning         8
# 1         2  2024-12-14  South  Monitor  Accessories     Returning         2
# 2         3  2024-09-27  North    Phone  Accessories           New         5
#
#    price  discount    sales
# 0    590      0.09  4295.20
# 1    262      0.18   429.68
# 2    512      0.09  2329.60

# %%
df_sales.shape
# Out:
# (500, 10)

# %%
df_sales.columns
# Out:
# Index(['order_id', 'date', 'region', 'product', 'category', 'customer_type',
#        'quantity', 'price', 'discount', 'sales'],
#       dtype='str')

# %%
df_sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       500 non-null    int64
#  1   date           500 non-null    str
#  2   region         500 non-null    str
#  3   product        500 non-null    str
#  4   category       500 non-null    str
#  5   customer_type  500 non-null    str
#  6   quantity       500 non-null    int64
#  7   price          500 non-null    int64
#  8   discount       500 non-null    float64
#  9   sales          500 non-null    float64
# dtypes: float64(2), int64(3), str(5)
# memory usage: 39.2 KB

# %%
df_sales.customer_type.value_counts()
# Out:
# customer_type
# Returning    261
# New          239
# Name: count, dtype: int64

# %%
df_sales.customer_type.value_counts()
# Out:
# customer_type
# Returning    261
# New          239
# Name: count, dtype: int64

# %%
df_sales.category.value_counts()
# Out:
# category
# Electronics    266
# Accessories    234
# Name: count, dtype: int64

# %%
df_sales.isnull().sum()
# Out:
# order_id         0
# date             0
# region           0
# product          0
# category         0
# customer_type    0
# quantity         0
# price            0
# discount         0
# sales            0
# dtype: int64

# %%
df_sales.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_sales.describe(include='all')
# Out:
#           order_id        date region product     category customer_type  \
# count   500.000000         500    500     500          500           500
# unique         NaN         267      4       6            2             2
# top            NaN  2024-04-08  North   Mouse  Electronics     Returning
# freq           NaN           6    151      96          266           261
# mean    250.500000         NaN    NaN     NaN          NaN           NaN
# std     144.481833         NaN    NaN     NaN          NaN           NaN
# min       1.000000         NaN    NaN     NaN          NaN           NaN
# 25%     125.750000         NaN    NaN     NaN          NaN           NaN
# 50%     250.500000         NaN    NaN     NaN          NaN           NaN
# 75%     375.250000         NaN    NaN     NaN          NaN           NaN
# max     500.000000         NaN    NaN     NaN          NaN           NaN
#
#           quantity        price   discount         sales
# ...

# %%
df_customer.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_id         500 non-null    int64
#  1   customer_rating  500 non-null    int64
# dtypes: int64(2)
# memory usage: 7.9 KB

# %%
df_customer.describe(include='all')
# Out:
#          order_id  customer_rating
# count  500.000000       500.000000
# mean   250.500000         2.480000
# std    144.481833         1.118975
# min      1.000000         1.000000
# 25%    125.750000         1.000000
# 50%    250.500000         2.500000
# 75%    375.250000         3.000000
# max    500.000000         4.000000

# %%
df_merge = pd.merge(df_customer,df_sales, on='order_id', how='inner')
df_merge.head(3)
# Out:
#    order_id  customer_rating        date region  product     category  \
# 0         1                1  2024-04-12   East   Laptop  Electronics
# 1         2                1  2024-12-14  South  Monitor  Accessories
# 2         3                2  2024-09-27  North    Phone  Accessories
#
#   customer_type  quantity  price  discount    sales
# 0     Returning         8    590      0.09  4295.20
# 1     Returning         2    262      0.18   429.68
# 2           New         5    512      0.09  2329.60

# %%
df_merge = pd.merge(df_customer,df_sales, on='order_id', how='outer')
df_merge.head(2)
# Out:
#    order_id  customer_rating        date region  product     category  \
# 0         1                1  2024-04-12   East   Laptop  Electronics
# 1         2                1  2024-12-14  South  Monitor  Accessories
#
#   customer_type  quantity  price  discount    sales
# 0     Returning         8    590      0.09  4295.20
# 1     Returning         2    262      0.18   429.68

# %%
df_merge.columns
# Out:
# Index(['order_id', 'customer_rating', 'date', 'region', 'product', 'category',
#        'customer_type', 'quantity', 'price', 'discount', 'sales'],
#       dtype='str')

# %%
df_merge.drop(columns=['discount'], inplace=True)

# %%
df_merge.columns
# Out:
# Index(['order_id', 'customer_rating', 'date', 'region', 'product', 'category',
#        'customer_type', 'quantity', 'price', 'sales'],
#       dtype='str')

# %%
df_merge.region.value_counts()
# Out:
# region
# North    151
# East     118
# South    116
# West     115
# Name: count, dtype: int64

# %%
df_merge.groupby('product')['sales'].sum()
# Out:
# product
# Keyboard    260675.81
# Laptop      317281.14
# Monitor     281509.14
# Mouse       299401.20
# Phone       245079.73
# Tablet      262582.76
# Name: sales, dtype: float64

# %%
bins = [0, 100, 500, 1000, 5000]
labels = ['low', 'medium', 'high', 'very high']
df_merge['df_sales'] = pd.cut(df_merge['sales'], bins = bins, labels = labels)

# %%
df_merge
# Out:
#      order_id  customer_rating        date region   product     category  \
# 0           1                1  2024-04-12   East    Laptop  Electronics
# 1           2                1  2024-12-14  South   Monitor  Accessories
# 2           3                2  2024-09-27  North     Phone  Accessories
# 3           4                1  2024-04-16   West     Mouse  Electronics
# 4           5                4  2024-03-12   West     Phone  Electronics
# ..        ...              ...         ...    ...       ...          ...
# 495       496                3  2024-11-20  South     Mouse  Accessories
# 496       497                4  2024-01-04  North     Phone  Accessories
# 497       498                4  2024-01-16  South  Keyboard  Electronics
# 498       499                1  2024-10-06  North     Phone  Accessories
# 499       500                1  2024-12-01  North   Monitor  Electronics
#
#     customer_type  quantity  price    sales   df_sales
# ...

# %%
df_merge.set_index('order_id', inplace=True)

# %%
df_merge.to_csv('merge_data.csv', index=False)

# %%
df_merge
# Out:
#           customer_rating        date region   product     category  \
# order_id
# 1                       1  2024-04-12   East    Laptop  Electronics
# 2                       1  2024-12-14  South   Monitor  Accessories
# 3                       2  2024-09-27  North     Phone  Accessories
# 4                       1  2024-04-16   West     Mouse  Electronics
# 5                       4  2024-03-12   West     Phone  Electronics
# ...                   ...         ...    ...       ...          ...
# 496                     3  2024-11-20  South     Mouse  Accessories
# 497                     4  2024-01-04  North     Phone  Accessories
# 498                     4  2024-01-16  South  Keyboard  Electronics
# 499                     1  2024-10-06  North     Phone  Accessories
# 500                     1  2024-12-01  North   Monitor  Electronics
#
#          customer_type  quantity  price    sales   df_sales
# order_id
# 1            Returning         8    590  4295.20  very high
# ...

# %%
df_merge['sales'].plot(kind='hist', bins=5, title='Sales Distribution')
# Out:
# <Axes: title={'center': 'Sales Distribution'}, ylabel='Frequency'>

# %%
df_merge.groupby('product')['sales'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='product'>

# %%
df_merge['sales'].plot(kind='hist', bins=5, title='Sales Distribution')
# Out:
# <Axes: title={'center': 'Sales Distribution'}, ylabel='Frequency'>

# %%
df_merge.groupby('quantity')['sales'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='quantity'>
