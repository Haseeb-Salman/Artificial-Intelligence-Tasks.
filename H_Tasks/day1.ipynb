# %%
d = {"name": "Ali", "age": 20, "PhNo.": [1234567890]}
print(d)
d["name"] = "Ahmad"
# print(d)
d["age"] = 50
# print(d)
d["PhNo."] = [98745632]
print("\nModified dictionary: \n")
print(d)
print("\nAdding a new phone number to the list of phone numbers: \n")
d["PhNo."].append(5454546)
print(d)
print("\nReplacing the first number with new one:  \n")
d["PhNo."][0]=22222222  
print(d)
print("\nClear the dictionary: \n")
d.clear()  
print(d)

# %%
tpl = (10, 5, 8)
print(tpl)
tpl = tpl + (15,)  
print(tpl)
tpl = tpl[:2] + (20,) + tpl[3:]  
print(tpl)
del tpl 
print("tpl is deleted !")
# Out:
# (10, 5, 8)
# (10, 5, 8, 15)
# (10, 5, 20, 15)
# tpl is deleted !

# %%
lst = [1, 4, 10, 3,100,56]
lst.append(8)
print(lst)          
lst.remove(100)
print(lst)          
print(lst[2:5])           
print(len(lst))
del lst
print("lst is deleted !")
# Out:
# [1, 4, 10, 3, 100, 56, 8]
# [1, 4, 10, 3, 56, 8]
# [10, 3, 56]
# 6
# lst is deleted !

# %%
x = 1

while x <= 10:
    print("4 *",x ," = " , 4*x )
    x += 1
# Out:
# 4 * 1  =  4
# 4 * 2  =  8
# 4 * 3  =  12
# 4 * 4  =  16
# 4 * 5  =  20
# 4 * 6  =  24
# 4 * 7  =  28
# 4 * 8  =  32
# 4 * 9  =  36
# 4 * 10  =  40

# %%
while True:
    print("Press 1 for : Enter Your name.")
    print("Press 2 for : Enter Your F.Name.")
    print("Press 3 for : Enter Your age.")
    print("Press 4 for : Enter Your Gender.")
    print("Press 5 for : Exit")
    print("Enter Your Choice : ")
    num = int (input())

    if num == 1:
        name = input("Enter your name: ")
        print("your name is : ", name)
    elif num == 2:
        fName = input("Enter Your F.Name: ")
        print("your fName is : ", fName)
    elif num == 3:
        age = int (input("Enter your age: "))
        print("your age is : ", age)
    elif num == 4:
        Gender = input("Enter Your Gender: ")
        print("your gender is : ", Gender)
    elif num == 5:
        print("Program Exit Successfully")
        break
    else:
        print("Invalid input")
# Out:
# Press 1 for : Enter Your name.
# Press 2 for : Enter Your F.Name.
# Press 3 for : Enter Your age.
# Press 4 for : Enter Your Gender.
# Press 5 for : Exit
# Enter Your Choice :
# your name is :  haseeb
# Press 1 for : Enter Your name.
# Press 2 for : Enter Your F.Name.
# Press 3 for : Enter Your age.
# Press 4 for : Enter Your Gender.
# Press 5 for : Exit
# Enter Your Choice :
# Invalid input
# Press 1 for : Enter Your name.
# Press 2 for : Enter Your F.Name.
# Press 3 for : Enter Your age.
# Press 4 for : Enter Your Gender.
# Press 5 for : Exit
# Enter Your Choice :
# Invalid input
# Press 1 for : Enter Your name.
# Press 2 for : Enter Your F.Name.
# Press 3 for : Enter Your age.
# Press 4 for : Enter Your Gender.
# Press 5 for : Exit
# Enter Your Choice :
# Invalid input
# Press 1 for : Enter Your name.
# Press 2 for : Enter Your F.Name.
# Press 3 for : Enter Your age.
# Press 4 for : Enter Your Gender.
# Press 5 for : Exit
# Enter Your Choice :
# Program Exit Successfully

# %%
sum = lambda a, b: a + b
print(sum(5, 10))
# Out:
# 15

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)
print(factorial(5))
# Out:
# 120

# %%
def sum(a, b):
    return a+b
print(sum(5, 10))
# Out:
# 15

# %%
def sqr(x):
    return x*x
print(sqr(4))
# Out:
# 16

# %%
def info(name, age):
    print("name: ", name)
    print("age: ", age)
    
info("Ali", 20)
# Out:
# name:  Ali
# age:  20

# %%
def info(name = "Ali"):
    print("name = ", name)
info()
# Out:
# name =  Ali

# %%
def even(n):
    return n%2 == 0
print(even(8))
# Out:
# True

# %%
def factorial(n):
    f = 1
    for i in range(1, n+1):
        f *= i
    return f
print(factorial(4))
# Out:
# 24

# %%
def show(*nums):
    print(nums)
show(1, 2, 3, 4, 5)
# Out:
# (1, 2, 3, 4, 5)

# %%
def person(**data):
    print(data)
person(name = "Ali", age = 20, PhNo = 1234567890)
# Out:
# {'name': 'Ali', 'age': 20, 'PhNo': 1234567890}

# %%
def outer():
    def inner():
        print("This is inner function")
    inner()
outer()
# Out:
# This is inner function

# %%
x = 10 
def show():
    print(x)
show()
# Out:
# 10

# %%
x = int(input("Enter a number: "))
i = 1
while i <= 10:
    print(x, "*", i, "=", x*i)
    i += 1

# %%
def test():
    y = 5
    print(y)
test()
# Out:
# 5

# %%
x = 10
def change():
    x = 5
    print("Inside function, x =", x)
change()
print("Outside function, x =", x)
# Out:
# Inside function, x = 5
# Outside function, x = 10

# %%
x = 10
def modify():
    global x
    x = 50
modify()
print("Outside function, x =", x)
# Out:
# Outside function, x = 50

# %%
def outer():
    z = 7
    def inner():
        print(z)
    inner()
outer()
# Out:
# 7

# %%
def counter():
    count = 0.12
    count += 1
    print(count)
counter()
# Out:
# 1.12

# %%
a = 1
b = 2
def swap():
    global a, b
    a, b = b, a
swap()
print(a, b)
# Out:
# 2 1

# %%
def f():
    x = 1
    def g():
        nonlocal x
        x = 2
    g()
    print(x)
f()
# Out:
# 2

# %%
def calculator():
    while True:
    
        x = int (input("Enter a number: "))
        y = int (input("Enter another number: "))
        op = input("Enter an operator (+, -, *, /): ")
        if op == '+':
            print("Result: ", x + y)
        elif op == '-':
            print("Result: ", x - y)
        elif op == '*':
            print("Result: ", x * y)
        elif op == '/':
            if y != 0:
                print("Result: ", x / y)
            else:
                print("Error: Division by zero is not allowed.")
        elif op == 'exit':
            print("Exiting the calculator. Goodbye!")
            break
        else:
            print("Invalid operator. Please try again.")
calculator()
# Out:
# Result:  24
# Exiting the calculator. Goodbye!

# %%
name = "Ali"
def display():
    print(name)
display()
# Out:
# Ali

# %%
def demo():
    p = 3
    print(p)
demo()
# Out:
# 3

# %%
add = lambda a, b: a + b
print(add(5, 10))
# Out:
# 15

# %%
square = lambda x: x * x
print(square(4))
# Out:
# 16

# %%
even = lambda n: n % 2 == 0
print(even(8))
# Out:
# True

# %%
nums = [1, 2, 3, 4, 5]
print(list(map(lambda x: x * 2, nums)))
# Out:
# [2, 4, 6, 8, 10]

# %%
nums = [1, 2, 3, 4, 5]
print(list(filter(lambda x: x % 2 == 0, nums)))
# Out:
# [2, 4]

# %%
pairs = [(1, 2), (2, 1), (3, 2)]
pairs.sort(key=lambda x: x[1])
print(pairs)
# Out:
# [(2, 1), (1, 2), (3, 2)]

# %%
mul = lambda a, b, c :  a * b * c
print(mul(2, 3, 4))
# Out:
# 24

# %%
f = lambda : "Hello"
print(f())
# Out:
# Hello

# %%
nums = [1, 2, 3, 4, 5]
print(sorted(nums, key=lambda x: -x))
# Out:
# [5, 4, 3, 2, 1]

# %%
length = lambda s: len(s)
print(length("Hello, World!"))
# Out:
# 13

# %%
name = input("Enter your name: ")
age = int (input("Enter your age: "))
choice = input("Enter your choice: ")
print("your name is : ", name)
print("your age is : ", age)
print("your choice is : ", choice)

# %%
x = int(input("Enter a number: "))
for i in range(1, 11):
    print(x, "*", i, "=", x*i)
# Out:
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50
