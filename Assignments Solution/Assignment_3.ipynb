# %% [markdown]
# # Assignment 2
# The Shopping List Manager

# %%
shopping_list = ["milk", "bread", "eggs", "apples", "chicken"] #creating an list whoes name is shopping_list which ha multiple items
shopping_list2 = shopping_list
print("Initial Shopping List : ",shopping_list) #printing the entire list
print("The Thirld item is : ",shopping_list[2]) #printing the thirld item from the list
# Out:
# Initial Shopping List :  ['milk', 'bread', 'eggs', 'apples', 'chicken']
# The Thirld item is :  eggs

# %% [markdown]
# Add two items

# %%
print('Adding meat and coffee')
shopping_list.append('meat')  #adding an new item at the end of the list
shopping_list.append('coffee') #adding an new item at the end of the list
print("Update shopping list: ",shopping_list) #display list
# Out:
# Adding meat and coffee
# Update shopping list:  ['milk', 'bread', 'eggs', 'apples', 'chicken', 'meat', 'coffee']

# %% [markdown]
# remove one item

# %%
print("removing \'eggs\'")
shopping_list.remove("eggs")  #removing an item from the list
print(shopping_list) #display list
# Out:
# removing 'eggs'
# ['milk', 'bread', 'apples', 'chicken', 'meat', 'coffee']

# %% [markdown]
# Create an Dictionary

# %%
item_price = {"milk": 2.52, 
              "bread" : 1.53, 
              "apples" : 0.99, 
              "meat" : 3.23}  #creating an dictionary from the list with float values
print("The price of apples is :  $", item_price["apples"]) # display specific item from the dictionary
# Out:
# The price of apples is :  $ 0.99

# %% [markdown]
# # final summary

# %%
print("Items to Buy : ", shopping_list) #display the final result of items
print("Price Lookup : ", item_price) #display the final result of items with prices
# Out:
# Items to Buy :  ['milk', 'bread', 'apples', 'chicken', 'meat', 'coffee']
# Price Lookup :  {'milk': 2.52, 'bread': 1.53, 'apples': 0.99, 'meat': 3.23}
