# %% [markdown]
# 1. Ask the user for their name and store it in a variable.

# %%
name = input("What is your name? ")  # Ask the user for their name and store it in the variable 'name'
print("Hello,", name, '!') # Greet the user by their name
# Out:
# Hello, HASEEB !

# %% [markdown]
# 2. Ask the user for their birth year (as an integer) and store it.

# %%
birth_year = int(input("What year were you born? ")) # Ask the user for their birth year and store it in the variable 'birth_year'
print("You were born in ", birth_year, ".")  #Shows the birth year of the user
# Out:
# You were born in  2006 .

# %% [markdown]
# 3. Ask the user for their current age (as an integer) and store it.

# %%
age = int(input("What is your current age? "))# Ask the user for their current age and store it in the variable 'age' 
print("Your current age? ", age)  #shows the user age
# Out:
# Your current age?  19

# %% [markdown]
# 4. Calculate and print the year they will turn 100 years old. (Hint: 100 - age + current_year).

# %%
# Calculate the year when the user will turn 100 years oldyear = 100 - age + birth_year 
print("You will turn 100 in the year ", year, ".") # Print the year when the user will turn 100 years old
# Out:
# You will turn 100 in the year  -11 .

# %% [markdown]
# 5. Ask the user for a lucky number (as a float).

# %%
lucky_number = float(input("Enter your lucky number: "))  # Ask the user for their lucky number and store it in the variable 'lucky_number'
print("Your lucky number is ", lucky_number, ".")# Print the user's lucky number
# Out:
# Your lucky number is  17.0 .

# %% [markdown]
# 6. Print a summary message that includes all the information you've collected. Use appropriate data types and typecasting.

# %%
print('-'* 4, 'Personal Assistant Summary', '-'* 4 )
print("Hello,", name, '!')# Greet the user by their name
print("You were born in ", birth_year, ".")  # Print the user's birth year
print("You are currently ", age, " years old.")  # Print the user's current age
print("You will turn 100 in the year ", year, ".")  # Print the year when the user will turn 100 years old
print("Your lucky number is ", lucky_number, ".")  # Print the user's lucky number
print('-'*36)
# Out:
# ---- Personal Assistant Summary ----
# Hello, HASEEB !
# You were born in  2006 .
# You are currently  19  years old.
# You will turn 100 in the year  -11 .
# Your lucky number is  17.0 .
# ------------------------------------
