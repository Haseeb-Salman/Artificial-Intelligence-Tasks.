# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('D:\DEV VELLY\Datasets\student_marks.csv')
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\HASEEB\AppData\Local\Temp\ipykernel_18736\1710618097.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df=pd.read_csv('D:\DEV VELLY\Datasets\student_marks.csv')
#      Unnamed: 0.1  Unnamed: 0  Study_Hours      Marks
# 0               0           0     3.745401  16.591606
# 1               1           1     9.507143  30.850740
# 2               2           2     7.319939  27.720214
# 3               3           3     5.986585  24.180926
# 4               4           4     1.560186  10.800140
# ..            ...         ...          ...        ...
# 995           995         995     0.915821   5.107417
# 996           996         996     9.173136  31.295869
# 997           997         997     1.368186   9.030485
# 998           998         998     9.502374  32.648516
# 999           999         999     4.460058  16.995331
#
# [1000 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Study_Hours', 'Marks'], dtype='str')

# %%
df=df[['Study_Hours','Marks']]
df.head(5)
# Out:
#    Study_Hours      Marks
# 0     3.745401  16.591606
# 1     9.507143  30.850740
# 2     7.319939  27.720214
# 3     5.986585  24.180926
# 4     1.560186  10.800140

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Study_Hours  1000 non-null   float64
#  1   Marks        1000 non-null   float64
# dtypes: float64(2)
# memory usage: 15.8 KB

# %%
df.describe()
# Out:
#        Study_Hours        Marks
# count  1000.000000  1000.000000
# mean      4.902566    19.905488
# std       2.921374     8.895874
# min       0.046320     1.239875
# 25%       2.359733    11.911571
# 50%       4.968074    20.137216
# 75%       7.443196    27.246988
# max       9.997177    38.562591

# %%
df.isnull().sum()
# Out:
# Study_Hours    0
# Marks          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.Figure(figsize=(10,5))
plt.scatter(df['Study_Hours'],y=df['Marks'])
plt.xlabel('study hours')
plt.ylabel('marks')
plt.title('study hrs vs marks')
plt.show()

# %%
df.columns
# Out:
# Index(['Study_Hours', 'Marks'], dtype='str')

# %% [markdown]
# ## data split

# %%
X=df[['Study_Hours']] #independent / features
Y=df['Marks']


Y.shape
# Out:
# (1000,)

# %%
type(Y)
# Out:
# pandas.Series

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,
                                               random_state=40)
x_test.shape
# Out:
# (200, 1)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import r2_score

r2_score(y_test,y_pred)
# Out:
# 0.9379706088446806

# %%
model.coef_
# Out:
# array([2.97636809])

# %%
model.intercept_
# Out:
# np.float64(5.3051568473396795)

# %%
y_pred
# Out:
# array([23.3547179 , 11.21966699, 31.99688096,  7.69320845, 10.71693716,
#        13.66680196, 19.9374549 , 14.9248658 , 20.28034392, 23.01686652,
#         8.68254653, 18.71500874, 18.04949323,  8.47791324, 33.91372612,
#        20.53456098, 16.45500719, 25.87000724,  8.86971873,  6.32868582,
#        14.73792229, 17.47710181, 13.462049  , 24.45178214, 13.89774512,
#        19.81290352, 26.32552517, 17.51966324, 10.5766226 ,  8.75384657,
#        16.52441058,  7.54153381, 10.70534325, 19.07621037, 24.65047591,
#        27.27175394, 32.25265713, 19.05615018, 34.54436057, 10.09139638,
#        19.96749328,  9.10241628,  9.72990685, 17.65171217, 21.4261848 ,
#        29.21970691, 34.96873769, 26.38000314, 24.11095804, 12.66714683,
#        15.47889945, 16.97978346, 32.07980744, 20.74627539, 28.4140645 ,
#         9.45040638,  5.51207784, 27.52348886, 27.57611954, 19.95234918,
#        16.24973269, 32.21624776, 22.77170865, 17.64589698, 33.18865831,
# ...

# %%
model.predict([[20]])
# Out:
# c:\Users\HASEEB\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([64.83251875])

# %%
x_test
# Out:
#      Study_Hours
# 204     6.064291
# 71      1.987157
# 594     8.967884
# 672     0.802337
# 14      1.818250
# ..           ...
# 647     6.791023
# 797     5.651332
# 605     4.607788
# 611     7.994104
# 988     2.464020
#
# [200 rows x 1 columns]

# %%
y_test
# Out:
# 204    23.185667
# 71      9.850516
# 594    34.845993
# 672     7.888519
# 14      8.292636
#          ...
# 647    23.166653
# 797    24.283474
# 605    19.421948
# 611    27.626881
# 988    12.638471
# Name: Marks, Length: 200, dtype: float64

# %%
model.predict([[6.064291
]])
# Out:
# c:\Users\HASEEB\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([23.3547191])

# %%
plt.scatter(x_test,y_test,color='red',label='test data')
plt.plot(x_test,y_pred,color='green',label='R line')
plt.legend()

# %%
testing=r2_score(y_test,y_pred)


y_train_pred=model.predict(x_train)
training=r2_score(y_train,y_train_pred)

# %%
plt.scatter(x_train,y_train,color='blue',label='training data')

plt.scatter(x_test,y_test,color='red',label='test data')
plt.plot(x_test,y_pred,color='green',label='R line')
plt.legend()

# %%
print(testing)
print(training)
# Out:
# 0.9379706088446806
# 0.9536718506642291

# %%
import pickle


with open("marks_model", 'wb') as f:
    pickle.dump(model, f)
